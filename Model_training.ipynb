# %%
from google.colab import drive 
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd /content/drive/My Drive/ANPD_Using_Yolov3
# Out:
# /content/drive/My Drive/ANPD_Using_Yolov3

# %%
# !git clone https://github.com/AlexeyAB/darknet
# Out:
# Cloning into 'darknet'...
# remote: Enumerating objects: 15185, done.
# remote: Total 15185 (delta 0), reused 0 (delta 0), pack-reused 15185
# Receiving objects: 100% (15185/15185), 13.56 MiB | 8.32 MiB/s, done.
# Resolving deltas: 100% (10308/10308), done.
# Checking out files: 100% (2038/2038), done.

# %%
# %cd darknet
# Out:
# /content/drive/My Drive/ANPD_Using_Yolov3/darknet

# %%
# !make
# Out:
# mkdir -p ./obj/
# mkdir -p backup
# chmod +x *.sh
# g++ -std=c++11 -std=c++11 -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/image_opencv.cpp -o obj/image_opencv.o
# ./src/image_opencv.cpp: In function ‘void draw_detections_cv_v3(void**, detection*, int, float, char**, image**, int, int)’:
# ./src/image_opencv.cpp:946:23: warning: variable ‘rgb’ set but not used [-Wunused-but-set-variable]
#                  float rgb[3];
#                        ^~~
# ./src/image_opencv.cpp: In function ‘void draw_train_loss(char*, void**, int, float, float, int, int, float, int, char*, float, int, int, double)’:
# ./src/image_opencv.cpp:1147:13: warning: this ‘if’ clause does not guard... [-Wmisleading-indentation]
#              if (iteration_old == 0)
# ...

# %%
# %cd /content/drive/My Drive/ANPD_Using_Yolov3/Custom_weight
# Out:
# /content/drive/My Drive/ANPD_Using_Yolov3/Custom_weight

# %%
# !wget https://pjreddie.com/media/files/darknet53.conv.74
# Out:
# --2021-07-02 04:16:49--  https://pjreddie.com/media/files/darknet53.conv.74
# Resolving pjreddie.com (pjreddie.com)... 128.208.4.108
# Connecting to pjreddie.com (pjreddie.com)|128.208.4.108|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 162482580 (155M) [application/octet-stream]
# Saving to: ‘darknet53.conv.74’
#
# darknet53.conv.74   100%[===================>] 154.96M  41.6MB/s    in 4.1s
#
# 2021-07-02 04:16:54 (37.4 MB/s) - ‘darknet53.conv.74’ saved [162482580/162482580]

# %%
# %cd /content/drive/My Drive/ANPD_Using_Yolov3
# Out:
# /content/drive/My Drive/ANPD_Using_Yolov3

# %%
# !python Custom_data/creating-files-data-and-name.py

# %%
# !python Custom_data/creating-train-and-test-txt-files.py

# %%
# %cd /content/drive/My Drive/ANPD_Using_Yolov3
# Out:
# /content/drive/My Drive/ANPD_Using_Yolov3

# %%
# !chmod +x ./darknet/darknet

# %%
# !darknet/darknet
# Out:
# usage: darknet/darknet <function>

# %%
# !darknet/darknet detector train Custom_data/labelled_data.data darknet/cfg/yolov3-train.cfg Custom_weight/darknet53.conv.74 -dont_show
# Out:
# Streaming output truncated to the last 5000 lines.
#  total_bbox = 121167, rewritten_bbox = 0.000000 %
#
#  1926: 0.108817, 0.103605 avg loss, 0.001000 rate, 10.428647 seconds, 123264 images, 0.307286 hours left
# Loaded: 0.000080 seconds
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.811388), count: 3, class_loss = 0.000700, iou_loss = 0.110991, total_loss = 0.111691
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.752715), count: 1, class_loss = 0.126364, iou_loss = 0.068636, total_loss = 0.195000
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 0.000000, iou_loss = 0.000000, total_loss = 0.000000
#  total_bbox = 121171, rewritten_bbox = 0.000000 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.845756), count: 4, class_loss = 0.327076, iou_loss = 0.061271, total_loss = 0.388346
# ...
